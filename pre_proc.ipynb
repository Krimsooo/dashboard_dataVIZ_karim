# %%
import pandas as pd 
df = pd.read_csv('./datasets/full_2020.csv', parse_dates=['date_mutation'],low_memory=False)
df
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1           Vente
# 1              2020-2    2020-01-02                   1           Vente
# 2              2020-2    2020-01-02                   1           Vente
# 3              2020-2    2020-01-02                   1           Vente
# 4              2020-2    2020-01-02                   1           Vente
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1           Vente
# 2459556  2020-1075291    2020-12-16                   1           Vente
# 2459557  2020-1075291    2020-12-16                   1           Vente
# 2459558  2020-1075291    2020-12-16                   1           Vente
# 2459559  2020-1075292    2020-10-08                   1    Adjudication
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2459560 entries, 0 to 2459559
# Data columns (total 40 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id_mutation                   object
#  1   date_mutation                 datetime64[ns]
#  2   numero_disposition            int64
#  3   nature_mutation               object
#  4   valeur_fonciere               float64
#  5   adresse_numero                float64
#  6   adresse_suffixe               object
#  7   adresse_nom_voie              object
#  8   adresse_code_voie             object
#  9   code_postal                   float64
#  10  code_commune                  object
#  11  nom_commune                   object
#  12  code_departement              object
#  13  ancien_code_commune           float64
#  14  ancien_nom_commune            object
#  15  id_parcelle                   object
#  16  ancien_id_parcelle            object
# ...

# %%
df.drop('ancien_code_commune', axis=1)
df.drop('ancien_nom_commune', axis=1)
df.drop('ancien_id_parcelle', axis=1)
df.drop('numero_volume', axis=1)
df.drop('lot1_numero', axis=1)
df.drop('lot1_surface_carrez', axis=1)
df.drop('lot2_numero', axis=1)
df.drop('lot2_surface_carrez')
df.drop('lot3_numero', axis=1)
df.drop('lot3_surface_carrez', axis=1)
df.drop('lot4_numero', axis=1)
df.drop('lot4_surface_carrez', axis=1)
df.drop('lot5_numero', axis=1)
df.drop('lot5_surface_carrez', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13896/2243212942.py in <module>
#       6 df.drop('lot1_surface_carrez', axis=1)
#       7 df.drop('lot2_numero', axis=1)
# ----> 8 df.drop('lot2_surface_carrez')
#       9 df.drop('lot3_numero', axis=1)
#      10 df.drop('lot3_surface_carrez', axis=1)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2459560 entries, 0 to 2459559
# Data columns (total 40 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   id_mutation                   object
#  1   date_mutation                 datetime64[ns]
#  2   numero_disposition            int64
#  3   nature_mutation               object
#  4   valeur_fonciere               float64
#  5   adresse_numero                float64
#  6   adresse_suffixe               object
#  7   adresse_nom_voie              object
#  8   adresse_code_voie             object
#  9   code_postal                   float64
#  10  code_commune                  object
#  11  nom_commune                   object
#  12  code_departement              object
#  13  ancien_code_commune           float64
#  14  ancien_nom_commune            object
#  15  id_parcelle                   object
#  16  ancien_id_parcelle            object
# ...

# %%
import pandas as pd 
df = pd.read_csv('./datasets/full_2020.csv', parse_dates=['date_mutation'],low_memory=False)
df
# Out:
#           id_mutation date_mutation  numero_disposition nature_mutation  \
# 0              2020-1    2020-01-07                   1           Vente
# 1              2020-2    2020-01-02                   1           Vente
# 2              2020-2    2020-01-02                   1           Vente
# 3              2020-2    2020-01-02                   1           Vente
# 4              2020-2    2020-01-02                   1           Vente
# ...               ...           ...                 ...             ...
# 2459555  2020-1075291    2020-12-16                   1           Vente
# 2459556  2020-1075291    2020-12-16                   1           Vente
# 2459557  2020-1075291    2020-12-16                   1           Vente
# 2459558  2020-1075291    2020-12-16                   1           Vente
# 2459559  2020-1075292    2020-10-08                   1    Adjudication
#
#          valeur_fonciere  adresse_numero adresse_suffixe  \
# ...

# %%
df.sample(100000).to_csv("./datasets/full_2020_1.csv")
